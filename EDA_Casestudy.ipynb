# %% [markdown]
# Objectives of Exploratory Data Analysis

# %%
#import libraries
import numpy as np #faster data processing (arrays) and used for numberical data 
import pandas as pd #EDA purpose

# %%
#Loading the data 
data = pd.read_csv('titanic.csv')
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#understanding the dataset -->info(),describe(),columns(),unique(),value_count()
data.info() #complete information of dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
#reading columns 
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
#we will seperate the columns 
data.dtypes;
data.select_dtypes(include='object')
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
#we will seperate the columns 
data.dtypes;
data.select_dtypes(include='integer')
# Out:
#      PassengerId  Survived  Pclass  SibSp  Parch
# 0              1         0       3      1      0
# 1              2         1       1      1      0
# 2              3         1       3      0      0
# 3              4         1       1      1      0
# 4              5         0       3      0      0
# ..           ...       ...     ...    ...    ...
# 886          887         0       2      0      0
# 887          888         1       1      0      0
# 888          889         0       3      1      2
# 889          890         1       1      0      0
# 890          891         0       3      0      0
#
# [891 rows x 5 columns]

# %%
#we will seperate the columns 
data.dtypes;
data.select_dtypes(include='object')
data.select_dtypes(include=['int64','float'])
# Out:
#      PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0              1         0       3  22.0      1      0   7.2500
# 1              2         1       1  38.0      1      0  71.2833
# 2              3         1       3  26.0      0      0   7.9250
# 3              4         1       1  35.0      1      0  53.1000
# 4              5         0       3  35.0      0      0   8.0500
# ..           ...       ...     ...   ...    ...    ...      ...
# 886          887         0       2  27.0      0      0  13.0000
# 887          888         1       1  19.0      0      0  30.0000
# 888          889         0       3   NaN      1      2  23.4500
# 889          890         1       1  26.0      0      0  30.0000
# 890          891         0       3  32.0      0      0   7.7500
#
# [891 rows x 7 columns]

# %%
#getting total number of passenger list 
print('total number of passengers in the ship are',len(data))
# Out:
# total number of passengers in the ship are 891

# %%
#Statistical Distribution --> describe()
data.describe() #default --> numerical columns only
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data.describe(include='object') #To Describe object 
# top returns most occuring value 
# freq returns the count of most occuring value
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
#we try to understand the unique values in the columns 
data['Sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
data['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
data['Pclass'].unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
data['Survived'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
data['SibSp'].unique()
# Out:
# array([1, 0, 3, 4, 2, 5, 8], dtype=int64)

# %%
data['Parch'].unique()
# Out:
# array([0, 1, 2, 5, 3, 4, 6], dtype=int64)

# %%
#count of each Unique value 
data['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
data['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
data['Pclass'].value_counts()
data['Pclass'].value_counts(ascending=True)
# Out:
# Pclass
# 2    184
# 1    216
# 3    491
# Name: count, dtype: int64

# %%
data['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
data['Age'].value_counts()
# Out:
# Age
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 28.00    25
#          ..
# 36.50     1
# 55.50     1
# 0.92      1
# 23.50     1
# 74.00     1
# Name: count, Length: 88, dtype: int64

# %%
data['Name'].value_counts()
# Out:
# Name
# Braund, Mr. Owen Harris                     1
# Boulos, Mr. Hanna                           1
# Frolicher-Stehli, Mr. Maxmillian            1
# Gilinski, Mr. Eliezer                       1
# Murdlin, Mr. Joseph                         1
#                                            ..
# Kelly, Miss. Anna Katherine "Annie Kate"    1
# McCoy, Mr. Bernard                          1
# Johnson, Mr. William Cahoone Jr             1
# Keane, Miss. Nora A                         1
# Dooley, Mr. Patrick                         1
# Name: count, Length: 891, dtype: int64

# %%
data['Age'].value_counts().head(30) # to get top values and inside () we give number of samples count
# Out:
# Age
# 24.0    30
# 22.0    27
# 18.0    26
# 19.0    25
# 28.0    25
# 30.0    25
# 21.0    24
# 25.0    23
# 36.0    22
# 29.0    20
# 32.0    18
# 35.0    18
# 27.0    18
# 26.0    18
# 16.0    17
# 31.0    17
# 20.0    15
# 34.0    15
# 33.0    15
# 23.0    15
# 39.0    14
# 40.0    13
# 17.0    13
# 42.0    13
# 45.0    12
# 38.0    11
# 50.0    10
# 2.0     10
# 4.0     10
# 44.0     9
# Name: count, dtype: int64

# %%
# to get bottom values 
data['Age'].value_counts().tail(30)
# Out:
# Age
# 13.00    2
# 63.00    2
# 30.50    2
# 57.00    2
# 70.00    2
# 0.75     2
# 71.00    2
# 59.00    2
# 0.83     2
# 40.50    2
# 55.00    2
# 32.50    2
# 28.50    2
# 45.50    2
# 34.50    1
# 0.42     1
# 0.67     1
# 66.00    1
# 24.50    1
# 80.00    1
# 20.50    1
# 53.00    1
# 14.50    1
# 70.50    1
# 12.00    1
# 36.50    1
# 55.50    1
# 0.92     1
# 23.50    1
# 74.00    1
# Name: count, dtype: int64

# %%
# to get random samples 
data.sample(30)
# Out:
#      PassengerId  Survived  Pclass  \
# 404          405         0       3
# 559          560         1       3
# 480          481         0       3
# 43            44         1       2
# 261          262         1       3
# 238          239         0       2
# 159          160         0       3
# 307          308         1       1
# 287          288         0       3
# 225          226         0       3
# 726          727         1       2
# 599          600         1       1
# 886          887         0       2
# 149          150         0       2
# 763          764         1       1
# 310          311         1       1
# 846          847         0       3
# 73            74         0       3
# 487          488         0       1
# 777          778         1       3
# 753          754         0       3
# 85            86         1       3
# 21            22         1       2
# 114          115         0       3
# 645          646         1       1
# ...

# %%
# Data visualization --> mathplotlib ,seaborn
import matplotlib.pyplot as plt

# %%
plt.hist(data['Age'],bins=15,color='orange') #histogram is used for numerical data and bins is used for number of bars count 
plt.xlabel("Age")
plt.ylabel("Count")
plt.title("Age Distributrion")
plt.show() #to remove the data above the graph like only graph noo data

# %%
counts,edges,bars= plt.hist(data['Age'],bins=15,color='orange') #histogram is used for numerical data and bins is used for number of bars count 
plt.xlabel("Age")
plt.ylabel("Count")
plt.title("Age Distributrion")
plt.bar_label(bars)
plt.show() #to remove the data above the graph like only graph noo data

# %%
#bar plot representation 
data['Sex'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Sex'>

# %%
#bar plot representation 
data['Sex'].value_counts().plot(kind='barh') #barh --> horizontal bar
# Out:
# <Axes: ylabel='Sex'>

# %%
plt.bar(data['Survived'],data['Sex'],color='green')
plt.xlabel("Survived Rate ")
plt.ylabel("Gender")
plt.title("Survived rate vs gender")
plt.show()

# %%
data['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
#549/(549+342)
index=data['Survived'].value_counts().keys().tolist()
print(index)
labels=data['Survived'].value_counts().values.tolist()
print(labels)
# Out:
# [0, 1]
# [549, 342]

# %%
#pie chart 
plt.pie(x=labels,
        labels=['Dead','Alive'],
        colors=['red','orange'],
        autopct="%.1f%%",
shadow=True)
plt.title("Dead vs Alive")
plt.legend()
plt.show()

# %%
label = data['Sex'].value_counts().values.tolist()
plt.pie(x=label, labels=['M','F'], colors=['lightblue','lightyellow'], autopct="%.1f%%", shadow=True)
plt.legend()
plt.title("Gender Distribution")
plt.show()

# %%
#pairwise relationships are represented using scatterplots
plt.scatter(x=data['Age'],y=data['Fare'])
plt.title("Age vs Fare Scatter Plot")
plt.xlabel("Age")
plt.ylabel("Fare")
plt.show()

# %%
# !pip install plotly cufflinks
# Out:
# ...
# [notice] A new release of pip is available: 23.2.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import plotly as py
import plotly.graph_objects as go #for interactive graphs

# %%
from plotly.offline import init_notebook_mode,iplot
init_notebook_mode(connected=True)
# Out:
#         <script>
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.7.0.min"</script>

# %%
#let us visualize histogram 
trace = go.Histogram(x=data['Age'],nbinsx=50,marker={'color':'black'})
#layout define for the graph 
layout = go.Layout(title="Age Distribution")
#we combine 
fig = go.Figure(data=trace, layout=layout)
fig.show()

# %%
print(index)
print(labels)
# Out:
# [0, 1]
# [549, 342]

# %%
#we will display for piechart
trace = go.Pie(labels=['Dead','Alive'],
               values=[549,342],)
layout=go.Layout(title='Survived Distribution')
fig=go.Figure(data=trace,layout=layout)
fig

# %%
#Box plot andsScatter plot 
trace=go.Box(x=data['Pclass'],
             y=data['Age'],
             marker={'color':'black'})
layout=go.Layout(title="Age vs Pclass")
fig=go.Figure(data=trace,layout=layout)
fig

# %%
trace=go.Scatter(x=data['Age'],
                 y=data['Fare'],
                 mode='markers',
                 marker={'color':'black'})
layout=go.Layout(title="Age vs Fare Distribution")
fig=go.Figure(data=trace,layout=layout)
fig.show()

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
 # We can fill the missing values in the Age column with the mean
data['Age'] = data['Age'].fillna(data['Age'].mean())

# %%
data['Embarked']=data['Embarked'].fillna('S')

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %%
data.drop(columns=['Cabin'],inplace=True)

# %%
data.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
#Day2 Feature Engineering [ML concepts]
#process of creating,transforming or extracting important information from the features before making it machine learning model ready

# %%
data.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex        Age  \
# 0                            Braund, Mr. Owen Harris    male  22.000000
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                             Heikkinen, Miss. Laina  female  26.000000
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                           Allen, Mr. William Henry    male  35.000000
# 5                                   Moran, Mr. James    male  29.699118
# 6                            McCarthy, Mr. Timothy J    male  54.000000
# ...

# %%
#feature encoding --> transforming categorical values into numerical and in the above case we have Sex,Pclass,Embarked are categories
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Embarked'],
#       dtype='object')

# %%
#get_dummies()
Pclass=pd.get_dummies(data['Pclass'],dtype=int)
Pclass
# Out:
#      1  2  3
# 0    0  0  1
# 1    1  0  0
# 2    0  0  1
# 3    1  0  0
# 4    0  0  1
# ..  .. .. ..
# 886  0  1  0
# 887  1  0  0
# 888  0  0  1
# 889  1  0  0
# 890  0  0  1
#
# [891 rows x 3 columns]

# %%
#get_dummies()
Sex=pd.get_dummies(data['Sex'],dtype=int)
Sex
# Out:
#      female  male
# 0         0     1
# 1         1     0
# 2         1     0
# 3         1     0
# 4         0     1
# ..      ...   ...
# 886       0     1
# 887       1     0
# 888       1     0
# 889       0     1
# 890       0     1
#
# [891 rows x 2 columns]

# %%
#get_dummies()
embarked=pd.get_dummies(data['Embarked'],dtype=int)
embarked
# Out:
#      C  Q  S
# 0    0  0  1
# 1    1  0  0
# 2    0  0  1
# 3    0  0  1
# 4    0  0  1
# ..  .. .. ..
# 886  0  0  1
# 887  0  0  1
# 888  0  0  1
# 889  1  0  0
# 890  0  1  0
#
# [891 rows x 3 columns]

# %%
print(data['Embarked'])
# Out:
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: Embarked, Length: 891, dtype: object

# %%
#concatention of all tables 
final_data   = pd.concat([data,pclass,gender,embarked,
